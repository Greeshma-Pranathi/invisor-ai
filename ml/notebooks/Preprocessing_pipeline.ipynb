# %%
import pandas as pd

df = pd.read_csv("../docs/Sample Data/sample_customer_churn.csv")


print(df.head())

X = df.drop(columns=["churn"])
print(X)
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure_months  \
# 0        C001  Female               0     Yes         No             12
# 1        C002    Male               0      No         No              3
# 2        C003  Female               0     Yes        Yes             48
# 3        C004    Male               1      No         No              6
# 4        C005  Female               0     Yes        Yes             72
#
#     contract_type    payment_method  monthly_charges  total_charges  ...  \
# 0  Month-to-month  Electronic check             70.5          846.0  ...
# 1  Month-to-month      Mailed check             89.1          267.3  ...
# 2        One year       Credit card             55.2         2649.6  ...
# 3  Month-to-month  Electronic check             95.0          570.0  ...
# 4        Two year     Bank transfer             45.0         3240.0  ...
#
#   streaming_tv streaming_movies multiple_lines avg_monthly_usage_gb  \
# 0          Yes              Yes             No                140.2
# 1           No              Yes            Yes                220.5
# 2          Yes               No            Yes                 90.0
# 3           No              Yes             No                260.3
# 4          Yes              Yes            Yes                 60.5
#
#   support_tickets_last_6m late_payments_last_year autopay_enabled  \
# 0                       2                       1              No
# 1                       3                       2              No
# 2                       0                       0             Yes
# 3                       4                       3              No
# 4                       0                       0             Yes
#
#    billing_cycle  region  churn
# 0        Monthly   South      1
# 1        Monthly   North      1
# 2      Quarterly    East      0
# 3        Monthly   South      1
# 4      Quarterly    West      0
#
# [5 rows x 24 columns]
#    customer_id  gender  senior_citizen partner dependents  tenure_months  \
# 0         C001  Female               0     Yes         No             12
# 1         C002    Male               0      No         No              3
# 2         C003  Female               0     Yes        Yes             48
# 3         C004    Male               1      No         No              6
# 4         C005  Female               0     Yes        Yes             72
# 5         C006    Male               0     Yes         No             24
# 6         C007  Female               0      No         No              2
# 7         C008    Male               0     Yes        Yes             60
# 8         C009  Female               1      No         No              9
# 9         C010    Male               0     Yes        Yes             36
# 10        C011  Female               0      No         No              1
# 11        C012    Male               0     Yes        Yes             84
# 12        C013  Female               0     Yes         No             18
# 13        C014    Male               1      No         No              4
# 14        C015  Female               0     Yes        Yes             96
#
#      contract_type    payment_method  monthly_charges  total_charges  ...  \
# 0   Month-to-month  Electronic check             70.5          846.0  ...
# 1   Month-to-month      Mailed check             89.1          267.3  ...
# 2         One year       Credit card             55.2         2649.6  ...
# 3   Month-to-month  Electronic check             95.0          570.0  ...
# 4         Two year     Bank transfer             45.0         3240.0  ...
# 5         One year       Credit card             65.4         1569.6  ...
# 6   Month-to-month  Electronic check             99.9          199.8  ...
# 7         Two year     Bank transfer             49.8         2988.0  ...
# 8   Month-to-month      Mailed check             85.6          770.4  ...
# 9         One year       Credit card             58.3         2098.8  ...
# 10  Month-to-month  Electronic check            102.4          102.4  ...
# 11        Two year     Bank transfer             42.7         3586.8  ...
# 12        One year       Credit card             68.9         1240.2  ...
# 13  Month-to-month      Mailed check             91.5          366.0  ...
# 14        Two year     Bank transfer             40.2         3859.2  ...
#
#    paperless_billing streaming_tv streaming_movies multiple_lines  \
# 0                Yes          Yes              Yes             No
# 1                Yes           No              Yes            Yes
# 2                 No          Yes               No            Yes
# 3                Yes           No              Yes             No
# 4                 No          Yes              Yes            Yes
# 5                Yes          Yes              Yes            Yes
# 6                Yes           No              Yes             No
# 7                 No          Yes              Yes            Yes
# 8                Yes           No               No             No
# 9                 No          Yes               No            Yes
# 10               Yes           No              Yes             No
# 11                No          Yes              Yes            Yes
# 12               Yes          Yes              Yes            Yes
# 13               Yes           No              Yes             No
# 14                No          Yes              Yes            Yes
#
#    avg_monthly_usage_gb support_tickets_last_6m late_payments_last_year  \
# 0                 140.2                       2                       1
# 1                 220.5                       3                       2
# 2                  90.0                       0                       0
# 3                 260.3                       4                       3
# 4                  60.5                       0                       0
# 5                 180.7                       1                       0
# 6                 300.1                       5                       4
# 7                  70.4                       0                       0
# 8                 210.9                       3                       2
# 9                  95.6                       1                       0
# 10                320.8                       6                       5
# 11                 55.2                       0                       0
# 12                165.0                       1                       0
# 13                240.6                       4                       3
# 14                 50.1                       0                       0
#
#     autopay_enabled  billing_cycle  region
# 0                No        Monthly   South
# 1                No        Monthly   North
# 2               Yes      Quarterly    East
# 3                No        Monthly   South
# 4               Yes      Quarterly    West
# 5               Yes        Monthly   North
# 6                No        Monthly    East
# 7               Yes      Quarterly   South
# 8                No        Monthly    West
# 9               Yes        Monthly   North
# 10               No        Monthly   South
# 11              Yes      Quarterly    East
# 12              Yes        Monthly    West
# 13               No        Monthly   North
# 14              Yes      Quarterly   South
#
# [15 rows x 23 columns]

# %%
numeric_features = X.select_dtypes(include=["int64", "float64"]).columns.tolist()
numeric_features
# Out:
# ['senior_citizen',
#  'tenure_months',
#  'monthly_charges',
#  'total_charges',
#  'avg_monthly_usage_gb',
#  'support_tickets_last_6m',
#  'late_payments_last_year']

# %%
categorical_features = X.select_dtypes(include=["object", "category"]).columns.tolist()
categorical_features
# Out:
# ['customer_id',
#  'gender',
#  'partner',
#  'dependents',
#  'contract_type',
#  'payment_method',
#  'internet_service',
#  'online_security',
#  'tech_support',
#  'paperless_billing',
#  'streaming_tv',
#  'streaming_movies',
#  'multiple_lines',
#  'autopay_enabled',
#  'billing_cycle',
#  'region']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# Numeric pipeline
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# Categorical pipeline
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(handle_unknown="ignore"))
])

# Full preprocessing pipeline
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

# %%
X = df.drop(columns=["churn"])
y = df["churn"]

X_processed = preprocessor.fit_transform(X)

X_processed.shape
# Out:
# (15, 57)
